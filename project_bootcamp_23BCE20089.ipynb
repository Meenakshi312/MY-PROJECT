# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(pd.read_excel(r'C:\Users\Dell\python Class\Global_Education.xlsx'))

# %%
df
# Out:
#     Countries and areas  Latitude    Longitude  OOSR_Pre0Primary_Age_Male  \
# 0           Afghanistan  33.939110   67.709953                          0
# 1               Albania  41.153332   20.168331                          4
# 2               Algeria  28.033886    1.659626                          0
# 3               Andorra  42.506285    1.521801                          0
# 4                Angola  11.202692   17.873887                         31
# ..                  ...        ...         ...                        ...
# 197           Venezuela   6.423750   66.589730                         14
# 198             Vietnam  14.058324  108.277199                          0
# 199               Yemen  15.552727   48.516388                         96
# 200              Zambia  13.133897   27.849332                          0
# 201            Zimbabwe  19.015438   29.154857                         60
#
#      OOSR_Pre0Primary_Age_Female  OOSR_Primary_Age_Male  \
# ...

# %%
df[["Countries and areas","Birth_Rate"]]
# Out:
#     Countries and areas  Birth_Rate
# 0           Afghanistan       32.49
# 1               Albania       11.78
# 2               Algeria       24.28
# 3               Andorra        7.20
# 4                Angola       40.73
# ..                  ...         ...
# 197           Venezuela       17.88
# 198             Vietnam       16.75
# 199               Yemen       30.45
# 200              Zambia       36.19
# 201            Zimbabwe       30.68
#
# [202 rows x 2 columns]

# %%
df.drop('OOSR_Pre0Primary_Age_Male',axis=1,inplace=True)
df.drop("OOSR_Pre0Primary_Age_Female",axis=1,inplace=True)
df.drop("OOSR_Primary_Age_Male",axis=1,inplace=True)
df.drop("OOSR_Primary_Age_Female",axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df.drop('OOSR_Pre0Primary_Age_Male',axis=1,inplace=True)
#       2 df.drop("OOSR_Pre0Primary_Age_Female",axis=1,inplace=True)
#       3 df.drop("OOSR_Primary_Age_Male",axis=1,inplace=True)
#
# File c:\Users\Dell\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
# ...

# %%
df
# Out:
#     Countries and areas  Latitude    Longitude  OOSR_Primary_Age_Female  \
# 0           Afghanistan  33.939110   67.709953                        0
# 1               Albania  41.153332   20.168331                        3
# 2               Algeria  28.033886    1.659626                        0
# 3               Andorra  42.506285    1.521801                        0
# 4                Angola  11.202692   17.873887                        0
# ..                  ...        ...         ...                      ...
# 197           Venezuela   6.423750   66.589730                       10
# 198             Vietnam  14.058324  108.277199                        0
# 199               Yemen  15.552727   48.516388                       21
# 200              Zambia  13.133897   27.849332                       13
# 201            Zimbabwe  19.015438   29.154857                        0
#
#      OOSR_Lower_Secondary_Age_Male  OOSR_Lower_Secondary_Age_Female  \
# ...

# %%
df.drop(df.index[50:],axis=0,inplace=True)

# %%
df
# Out:
#                  Countries and areas  Latitude    Longitude  \
# 0                        Afghanistan  33.939110   67.709953
# 1                            Albania  41.153332   20.168331
# 2                            Algeria  28.033886    1.659626
# 3                            Andorra  42.506285    1.521801
# 4                             Angola  11.202692   17.873887
# 5                           Anguilla  18.220554   63.068615
# 6                Antigua and Barbuda  17.060816   61.796428
# 7                          Argentina  38.416097   63.616672
# 8                            Armenia  40.069099   45.038189
# 9                          Australia  25.274398  133.775136
# 10                           Austria  47.516231   14.550072
# 11                        Azerbaijan  40.143105   47.576927
# 12                       The Bahamas  25.034280   77.396280
# 13                           Bahrain  26.066700   50.557700
# 14                        Bangladesh  23.684994   90.356331
# ...

# %%
df.loc[0]
# Out:
# Countries and areas                        Afghanistan
# Latitude                                      33.93911
# Longitude                                    67.709953
# OOSR_Primary_Age_Female                              0
# OOSR_Lower_Secondary_Age_Male                        0
# OOSR_Lower_Secondary_Age_Female                      0
# OOSR_Upper_Secondary_Age_Male                       44
# OOSR_Upper_Secondary_Age_Female                     69
# Completion_Rate_Primary_Male                        67
# Completion_Rate_Primary_Female                      40
# Completion_Rate_Lower_Secondary_Male                49
# Completion_Rate_Lower_Secondary_Female              26
# Completion_Rate_Upper_Secondary_Male                32
# Completion_Rate_Upper_Secondary_Female              14
# Grade_2_3_Proficiency_Reading                       22
# Grade_2_3_Proficiency_Math                          25
# Primary_End_Proficiency_Reading                     13
# ...

# %%
df.loc[0,"Unemployment_Rate"]
# Out:
# 11.12

# %%
df.loc[df.index[:11],["Longitude"]]
# Out:
#      Longitude
# 0    67.709953
# 1    20.168331
# 2     1.659626
# 3     1.521801
# 4    17.873887
# 5    63.068615
# 6    61.796428
# 7    63.616672
# 8    45.038189
# 9   133.775136
# 10   14.550072

# %%
df[df["Grade_2_3_Proficiency_Math"]>2]
# Out:
#       Countries and areas  Latitude    Longitude  OOSR_Primary_Age_Female  \
# 0             Afghanistan  33.939110   67.709953                        0
# 7               Argentina  38.416097   63.616672                        0
# 9               Australia  25.274398  133.775136                        0
# 13                Bahrain  26.066700   50.557700                        3
# 14             Bangladesh  23.684994   90.356331                        0
# 19                  Benin   9.307690    2.315834                       10
# 24                 Brazil  14.235004   51.925280                        1
# 28           Burkina Faso  12.238333    1.561593                       22
# 29                Burundi   3.373056   29.918886                        6
# 32               Cameroon   7.369722   12.354722                       13
# 33                 Canada  56.130366  106.346771                        0
# 35                   Chad  15.454166   18.732207                       35
# ...

# %%
import matplotlib.pyplot as plt
x = df["Unemployment_Rate"]
y = df["Birth_Rate"]
plt.plot(x,y,"orange")
plt.xlabel("Unemployment_Rate")
plt.ylabel("Birth_Rate")
x1 = list(range(50))
y1 = df["Unemployment_Rate"]
plt.plot(x1,y1,"black")
